# %%
n= int(input("enter the number"))
if(n%2==0):
  print ("even number")
else:
  print("odd number")
# Out:
# enter the number6
# even number

# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
c=int(input("enter 3rd number"))
if(a>b and a>c):
  print("a is grater:",a)
elif(b>c and b>a):
  print("b is grater:",b)
else:
  print("c is grater",c)
# Out:
# enter 1st number6
# enter 2nd number5
# enter 3rd number4
# a is grater: 6

# %%
year=int(input("enter year"))
if(year%4==0 and year%100!=0)or (year%400==0):
  print("leap yaer")
else:
  print("not a leap yaer")
# Out:
# enter year2023
# not a leap yaer

# %%
p=int(input("enter the perceent"))
if(p>=90 and p<=100):
  print("grade A:",p)
elif(p>=80 and p<90):
  print("grade B:",p)
elif(p>=70 and p<80):
  print("grade c:",p)
elif(p>=60 and p<70):
  print("grade d:",p)
elif(p<60):
  print("grade f:",p)
# Out:
# enter the perceent78
# grade c: 78

# %%
z= input("enter a alphabat")
if(z=="a") or(z=="e") or (z=="i") or (z=="o") or (z=="o"):
  print("vowels")
else:
    print("constant")
# Out:
# enter a alphabatd
# constant

# %%
a= int(input("enter a number"))
c= input("enter a operators")
b= int(input("enter a number"))
if (c=="+"):
  print("adition:",a+b)
elif(c=="-"):
  print("subtract:",a-b)
elif(c=="*"):
  print("multiplication:",a*b)
elif(c=="/"):
  print("divide:",a/b)
# Out:
# enter a number3
# enter a operators-
# enter a number2
# subtract: 1

# %%
a=int(input("enter a number"))
if(a>0):
  print("positive number")
elif(a==0):
  print("zero")
else:
  print("negative")
# Out:
# enter a number-1
# negative

# %%
username=input("enter username")
password=int(input("enter password"))
if(username=="admin") and (password==1234):
  print("loggin successful")
else:
  print("login failed")
# Out:
# enter username5
# enter password6
# login failed

# %%
a= int(input("enter number"))
b= int(input("enter number"))
c= int(input("enter number"))
if(a+b>c and b+c>a and a+c>b):
  print("vaild triangle")
# Out:
# enter number6
# enter number7
# enter number8
# vaild triangle

# %%
weight=int(input("enter your weight"))
height=int(input("enter your weight"))
bmi =weight/(height**2)
if(bmi<18.5):
  print("underweight")
elif(18.5<=bmi<24.9):
  print("normal bmi")
elif(25<=bmi<29.9):
  print("overweight")
elif(bmi>=30):
  print("obasity")
# Out:
# enter your weight250
# enter your weight3
# overweight

# %%
price =int(input("enter price"))
if(price>=1000):
  price=price-(price)*10/100
  print("discount 10%",price)
elif (price>=500 and price<1000):
  price= price-(price)*5/100
  print("discount 5%",price)
elif(price<500):
  print("no discount",price)
# Out:
# enter price2000
# discount 10% 1800.0

# %%
m= input("enter month:")
if(m=="january"):
  print("days:31")
elif(m=="febuary"):
  print("days:29")
elif(m=="march"):
  print("days;31")
elif(m=="april"):
  print("days:30")
elif(m=="may"):
  print("days;31")
elif(m=="june"):
  print("days:28")
elif(m=="july"):
  print("days;31")
elif(m=="augest"):
  print("days:28")
elif(m=="septamber"):
  print("days;31")
elif(m=="oct"):
  print("days:28")
elif(m=="nov"):
  print("days;31")
elif(m=="dec"):
  print("day;31")
else:
  print("invalid input")
# Out:
# enter monthdec
# day;31

# %%
y=int(input("enter age"))
if(y>=0 and y<=1):
  print("infants")
elif(y>=2 and y<=4):
  print("todller")
elif(y>=5 and y<=10):
  print("children")
elif(y>=13 and y<=19):
  print("teenagers")
elif(y>=20 and y<=59):
  print("adult")
else:
    print("senior")
# Out:
# enter age1
# infants

# %%
a= int(input("enter day"))
if(a==1):
  print("monday")
elif(a==2):
  print("tuesday")
elif(a==3):
  print("wednesday")
elif(a==4):
  print("thursday")
elif(a==5):
  print("friday")
elif(a==6):
  print("saturday")
elif(a==7):
  print("sunday")
else:
  print("input is not vaild")
# Out:
# enter day7
# sunday

# %%
balance=1000
option = int(input("enter number"))
if(option==1):
  print("cheeck balance:",balance)
elif(option == 2):
  amt = int(input("enter amount"))
  deposite=amt+balance
  print(deposite)
if (option==3):
  amt= int(input("enter withdrwal amt"))
  withdrawal =balance-amt
  print(withdrawal)
else:
  print("invalid input")
# Out:
# enter number3
# enter withdrwal amt300
# 700
